# %% [markdown]
# <a href="https://colab.research.google.com/github/Siddharth122001/Covid19-Prediction/blob/main/Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from datetime import date,time

# %%
df=pd.read_csv('/content/payroll_master.csv')
df.head()
# Out:
#    EmpID Gender JobCode   Salary DateOfBirth  DateOfHire
# 0   1919      M     TA2  $48,126   9/16/1958    6/7/1985
# 1   1653      F     ME2  $49,151  10/19/1962   8/12/1988
# 2   1400      M     ME1  $41,677   11/8/1965  10/19/1988
# 3   1350      F     FA3  $46,040    9/4/1963    8/1/1988
# 4   1401      M     TA3  $54,351  12/16/1948  11/21/1983

# %%
#1
df[['EmpID']].count()
# Out:
# EmpID    148
# dtype: int64

# %%
#2
df_gender1=df[df['Gender']=='F']
df_gender1.count()
# Out:
# EmpID          65
# Gender         65
# JobCode        65
# Salary         65
# DateOfBirth    65
# DateOfHire     65
# dtype: int64

# %%
#2
df_gender2=df[df['Gender']=='M']
df_gender2.count()
# Out:
# EmpID            83
# Gender           83
# JobCode          83
# Salary           83
# DateOfBirth      83
# DateOfHire       83
# Today            83
# Diff             83
# money_replace    83
# money_int        83
# dtype: int64

# %%
#3
df['Today']= date.today()
df[-1:]
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire       Today
# 147   1105      M     ME2  $48,727    3/4/1960  8/16/1988  2022-06-10

# %%
df['Today']=pd.to_datetime(df['Today'],format="%Y-%m-%d")
df['Today']
# Out:
# 0     2022-06-10
# 1     2022-06-10
# 2     2022-06-10
# 3     2022-06-10
# 4     2022-06-10
#          ...
# 143   2022-06-10
# 144   2022-06-10
# 145   2022-06-10
# 146   2022-06-10
# 147   2022-06-10
# Name: Today, Length: 148, dtype: datetime64[ns]

# %%
df['DateOfHire']=pd.to_datetime(df['DateOfHire'],format="%m/%d/%Y")
df['DateOfHire']
# Out:
# 0     1958-09-16
# 1     1962-10-19
# 2     1965-11-08
# 3     1963-09-04
# 4     1948-12-16
#          ...
# 143   1962-11-13
# 144   1964-07-11
# 145   1962-06-13
# 146   1961-05-04
# 147   1960-03-04
# Name: DateOfBirth, Length: 148, dtype: datetime64[ns]

# %%
df['Diff']= df['Today'] - df['DateOfHire']
df['Diff']
# Out:
# 0     13517 days
# 1     12355 days
# 2     12287 days
# 3     12366 days
# 4     14081 days
#          ...
# 143   13696 days
# 144   13655 days
# 145   13211 days
# 146   12975 days
# 147   12351 days
# Name: Diff, Length: 148, dtype: timedelta64[ns]

# %%
df.head()
# Out:
#    EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today       Diff
# 0   1919      M     TA2  $48,126   9/16/1958 1985-06-07 2022-06-10 13517 days
# 1   1653      F     ME2  $49,151  10/19/1962 1988-08-12 2022-06-10 12355 days
# 2   1400      M     ME1  $41,677   11/8/1965 1988-10-19 2022-06-10 12287 days
# 3   1350      F     FA3  $46,040    9/4/1963 1988-08-01 2022-06-10 12366 days
# 4   1401      M     TA3  $54,351  12/16/1948 1983-11-21 2022-06-10 14081 days

# %%
#4 salary 
df['money_int'] = df['Salary'].str.replace('$', '').str.replace(',','')
df['money_int'] = pd.to_numeric(df['money_int'])
df['money_int']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
# 0      48126
# 1      49151
# 2      41677
# 3      46040
# 4      54351
#        ...
# 143    46215
# 144    46175
# 145    46522
# 146    39138
# 147    48727
# Name: money_int, Length: 148, dtype: int64

# %%
df.head()
# Out:
#    EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today       Diff  \
# 0   1919      M     TA2  $48,126   9/16/1958 1985-06-07 2022-06-10 13517 days
# 1   1653      F     ME2  $49,151  10/19/1962 1988-08-12 2022-06-10 12355 days
# 2   1400      M     ME1  $41,677   11/8/1965 1988-10-19 2022-06-10 12287 days
# 3   1350      F     FA3  $46,040    9/4/1963 1988-08-01 2022-06-10 12366 days
# 4   1401      M     TA3  $54,351  12/16/1948 1983-11-21 2022-06-10 14081 days
#
#    money_replace  money_int
# 0          48126      48126
# 1          49151      49151
# 2          41677      41677
# 3          46040      46040
# 4          54351      54351

# %%
#total salary
df['money_int'].sum()
# Out:
# 8003784

# %%
#5
df[df['Gender']=='M']
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today  \
# 0     1919      M     TA2  $48,126   9/16/1958 1985-06-07 2022-06-10
# 2     1400      M     ME1  $41,677   11/8/1965 1988-10-19 2022-06-10
# 4     1401      M     TA3  $54,351  12/16/1948 1983-11-21 2022-06-10
# 5     1499      M     ME3  $60,235   4/29/1952 1978-06-11 2022-06-10
# 6     1101      M     SCP  $26,212    6/9/1960 1988-10-04 2022-06-10
# ..     ...    ...     ...      ...         ...        ...        ...
# 130   1076      M     PT1  $93,181  10/18/1970 1989-10-06 2022-06-10
# 134   1133      M     TA1  $38,781   7/16/1964 1990-02-15 2022-06-10
# 136   1418      M     ME1  $39,207    4/2/1955 1990-01-09 2022-06-10
# 137   1017      M     TA3  $57,201    1/1/1956 1979-10-20 2022-06-10
# 147   1105      M     ME2  $48,727    3/4/1960 1988-08-16 2022-06-10
#
#           Diff  money_replace  money_int
# 0   13517 days          48126      48126
# 2   12287 days          41677      41677
# ...

# %%
df[df['Gender']=='F']
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today  \
# 1     1653      F     ME2  $49,151  10/19/1962 1988-08-12 2022-06-10
# 3     1350      F     FA3  $46,040    9/4/1963 1988-08-01 2022-06-10
# 9     1479      F     TA3  $54,299  12/26/1966 1987-10-09 2022-06-10
# 13    1428      F     PT1  $96,274    4/7/1968 1989-11-19 2022-06-10
# 20    1437      F     FA3  $46,346   9/24/1958 1982-09-04 2022-06-10
# ..     ...    ...     ...      ...         ...        ...        ...
# 142   1130      F     FA1  $33,482   5/19/1969 1990-06-09 2022-06-10
# 143   1127      F     TA2  $46,215  11/13/1962 1984-12-10 2022-06-10
# 144   1433      F     FA3  $46,175   7/11/1964 1985-01-20 2022-06-10
# 145   1431      F     FA3  $46,522   6/13/1962 1986-04-09 2022-06-10
# 146   1122      F     FA2  $39,138    5/4/1961 1986-12-01 2022-06-10
#
#           Diff  money_replace  money_int
# 1   12355 days          49151      49151
# 3   12366 days          46040      46040
# ...

# %%
#7
df[['EmpID','JobCode']]
# Out:
#      EmpID JobCode
# 0     1919     TA2
# 1     1653     ME2
# 2     1400     ME1
# 3     1350     FA3
# 4     1401     TA3
# ..     ...     ...
# 143   1127     TA2
# 144   1433     FA3
# 145   1431     FA3
# 146   1122     FA2
# 147   1105     ME2
#
# [148 rows x 2 columns]

# %%
df['DateOfBirth']=pd.to_datetime(df['DateOfBirth'],format="%m/%d/%Y")
df['DateOfBirth']
# Out:
# 0     1958-09-16
# 1     1962-10-19
# 2     1965-11-08
# 3     1963-09-04
# 4     1948-12-16
#          ...
# 143   1962-11-13
# 144   1964-07-11
# 145   1962-06-13
# 146   1961-05-04
# 147   1960-03-04
# Name: DateOfBirth, Length: 148, dtype: datetime64[ns]

# %%
from datetime import date

# %%
today_date= date.today()
df['present_year']=today_date.year
df['present_year']
# Out:
# 0      2022
# 1      2022
# 2      2022
# 3      2022
# 4      2022
#        ...
# 143    2022
# 144    2022
# 145    2022
# 146    2022
# 147    2022
# Name: present_year, Length: 148, dtype: int64

# %%
df['yyyy'] = pd.to_datetime(df['DateOfBirth']).dt.year
df['yyyy']
# Out:
# 0      1958
# 1      1962
# 2      1965
# 3      1963
# 4      1948
#        ...
# 143    1962
# 144    1964
# 145    1962
# 146    1961
# 147    1960
# Name: yyyy, Length: 148, dtype: int64

# %%
df['Age']= df['present_year']-df['yyyy']
df['Age']
# Out:
# 0      64
# 1      60
# 2      57
# 3      59
# 4      74
#        ..
# 143    60
# 144    58
# 145    60
# 146    61
# 147    62
# Name: Age, Length: 148, dtype: int64

# %%
df.head()
# Out:
#    EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today       Diff  \
# 0   1919      M     TA2  $48,126  1958-09-16 1985-06-07 2022-06-10 13517 days
# 1   1653      F     ME2  $49,151  1962-10-19 1988-08-12 2022-06-10 12355 days
# 2   1400      M     ME1  $41,677  1965-11-08 1988-10-19 2022-06-10 12287 days
# 3   1350      F     FA3  $46,040  1963-09-04 1988-08-01 2022-06-10 12366 days
# 4   1401      M     TA3  $54,351  1948-12-16 1983-11-21 2022-06-10 14081 days
#
#    money_replace  money_int  Age  present_year  yyyy
# 0          48126      48126   64          2022  1958
# 1          49151      49151   60          2022  1962
# 2          41677      41677   57          2022  1965
# 3          46040      46040   59          2022  1963
# 4          54351      54351   74          2022  1948

# %%
#9
df[['EmpID','Age']]
# Out:
#      EmpID  Age
# 0     1919   64
# 1     1653   60
# 2     1400   57
# 3     1350   59
# 4     1401   74
# ..     ...  ...
# 143   1127   60
# 144   1433   58
# 145   1431   60
# 146   1122   61
# 147   1105   62
#
# [148 rows x 2 columns]

# %%
#10. month of employee born
df['born_month']=  pd.to_datetime(df['DateOfBirth']).dt.month
df[['born_month']]
# Out:
#      born_month
# 0             9
# 1            10
# 2            11
# 3             9
# 4            12
# ..          ...
# 143          11
# 144           7
# 145           6
# 146           5
# 147           3
#
# [148 rows x 1 columns]

# %%
#11
df[df['Age']>35]
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today  \
# 0     1919      M     TA2  $48,126  1958-09-16 1985-06-07 2022-06-10
# 1     1653      F     ME2  $49,151  1962-10-19 1988-08-12 2022-06-10
# 2     1400      M     ME1  $41,677  1965-11-08 1988-10-19 2022-06-10
# 3     1350      F     FA3  $46,040  1963-09-04 1988-08-01 2022-06-10
# 4     1401      M     TA3  $54,351  1948-12-16 1983-11-21 2022-06-10
# ..     ...    ...     ...      ...         ...        ...        ...
# 143   1127      F     TA2  $46,215  1962-11-13 1984-12-10 2022-06-10
# 144   1433      F     FA3  $46,175  1964-07-11 1985-01-20 2022-06-10
# 145   1431      F     FA3  $46,522  1962-06-13 1986-04-09 2022-06-10
# 146   1122      F     FA2  $39,138  1961-05-04 1986-12-01 2022-06-10
# 147   1105      M     ME2  $48,727  1960-03-04 1988-08-16 2022-06-10
#
#           Diff  money_replace  money_int  Age  present_year  yyyy  born_month
# ...

# %%
df[df['Age']>50]
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today  \
# 0     1919      M     TA2  $48,126  1958-09-16 1985-06-07 2022-06-10
# 1     1653      F     ME2  $49,151  1962-10-19 1988-08-12 2022-06-10
# 2     1400      M     ME1  $41,677  1965-11-08 1988-10-19 2022-06-10
# 3     1350      F     FA3  $46,040  1963-09-04 1988-08-01 2022-06-10
# 4     1401      M     TA3  $54,351  1948-12-16 1983-11-21 2022-06-10
# ..     ...    ...     ...      ...         ...        ...        ...
# 143   1127      F     TA2  $46,215  1962-11-13 1984-12-10 2022-06-10
# 144   1433      F     FA3  $46,175  1964-07-11 1985-01-20 2022-06-10
# 145   1431      F     FA3  $46,522  1962-06-13 1986-04-09 2022-06-10
# 146   1122      F     FA2  $39,138  1961-05-04 1986-12-01 2022-06-10
# 147   1105      M     ME2  $48,727  1960-03-04 1988-08-16 2022-06-10
#
#           Diff  money_replace  money_int  Age  present_year  yyyy  born_month
# ...

# %%
#12
df[['Age']].min()
# Out:
# Age             51
# money_int    25120
# dtype: int64

# %%
df[['Age']].max()
# Out:
# Age    80
# dtype: int64

# %%
df[df['Age']== 51]
# Out:
#      EmpID Gender JobCode   Salary DateOfBirth DateOfHire      Today  \
# 104   1111      M     NA1  $56,820  1971-07-18 1990-11-04 2022-06-10
# 127   1995      F     ME1  $40,334  1971-08-28 1991-09-23 2022-06-10
#
#           Diff  money_replace  money_int  Age  present_year  yyyy  born_month
# 104 11541 days          56820      56820   51          2022  1971           7
# 127 11218 days          40334      40334   51          2022  1971           8

# %%
df[df['Age']==80]
# Out:
#     EmpID Gender JobCode    Salary DateOfBirth DateOfHire      Today  \
# 23   1065      M     ME2   $49,126  1942-01-29 1985-01-10 2022-06-10
# 32   1118      M     PT3  $155,931  1942-01-19 1978-12-22 2022-06-10
#
#          Diff  money_replace  money_int  Age  present_year  yyyy  born_month
# 23 13665 days          49126      49126   80          2022  1942           1
# 32 15876 days         155931     155931   80          2022  1942           1
